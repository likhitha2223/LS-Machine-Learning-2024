# %% [markdown]
# # **CNN assignment**(Do read the note at the end)

# %% [markdown]
# Description: Here we are going to use CNN to classify images of elephants,tigers,cheetah's and crocodiles. Basically multiclass classificiation using CNN.

# %% [markdown]
# **Q.1** Import all required modules

# %%
#Your code here
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Q.2** Load data using image_dataset_from_directory(https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/MyDrive/data'

data = image_dataset_from_directory(
    data_dir,
    batch_size=32,
    image_size=(256, 256),
    label_mode='int'
)
# Out:
# Found 1657 files belonging to 4 classes.

# %% [markdown]
# *   Since data object is not iterable,we will create a nummpy iterator for data.
# *   Then use batch to iterate through our data

# %%
data_iterator=data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %% [markdown]
# Run the below code and batch code 2-3 times to visualise the labels given to different animals.

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# **Q.3** Map the data such that all pixel values lie between 0 and 1 using the **lambda function**

# %%
data = data.map(lambda x, y: (x / 255.0, y))

# %% [markdown]
# **Q.4** Split the data into train set and test set(and validation set if needed) using **data.take**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-class-take-method/) and **data.skip**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-skip-method/)

# %%
train_size = int(len(data) * 0.95)
test_size = int(len(data) * 0.05)

train_data = data.take(train_size)
test_data = data.skip(train_size).take(test_size)

# %% [markdown]
# **Creating the model**

# %% [markdown]
# **Q.5** Write code to create CNN model including fully connected layers with softmax as final layer.

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dense(4, activation='softmax')
# ])
# model = tf.keras.Sequential([
#     tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
#     tf.keras.layers.MaxPooling2D((2, 2)),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(4, activation='softmax')
# ])
model = tf.keras.Sequential([
    # Block 1
    tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.3),

    # Block 2
    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.3),

    # Block 3
    tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.4),

    # Block 4
    tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.4),

    # Global Average Pooling
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 256, 256, 32)      896
#
#  batch_normalization_11 (Ba  (None, 256, 256, 32)      128
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 32)      9248
#
#  batch_normalization_12 (Ba  (None, 256, 256, 32)      128
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 128, 128, 32)      0
#  ng2D)
#
#  dropout_7 (Dropout)         (None, 128, 128, 32)      0
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 64)      18496
#
#  batch_normalization_13 (Ba  (None, 128, 128, 64)      256
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 64)      36928
#
#  batch_normalization_14 (Ba  (None, 128, 128, 64)      256
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 64, 64, 64)        0
#  ng2D)
#
#  dropout_8 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 128)       73856
#
#  batch_normalization_15 (Ba  (None, 64, 64, 128)       512
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 128)       147584
#
#  batch_normalization_16 (Ba  (None, 64, 64, 128)       512
#  tchNormalization)
#
#  max_pooling2d_15 (MaxPooli  (None, 32, 32, 128)       0
#  ng2D)
#
#  dropout_9 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_17 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 256)       590080
#
#  batch_normalization_18 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_16 (MaxPooli  (None, 16, 16, 256)       0
#  ng2D)
#
#  dropout_10 (Dropout)        (None, 16, 16, 256)       0
#
#  global_average_pooling2d_1  (None, 256)               0
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 512)               131584
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 1309732 (5.00 MB)
# Trainable params: 1307812 (4.99 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________

# %% [markdown]
# **Q.6** Compile your model

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=10000,
    decay_rate=0.9,
    staircase=True
)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **Q.7** Fit your model with train set and make sure to keep **less epochs**(10-15) as the dataset size is very large.

# %%
history = model.fit(train_data, epochs=20, validation_data=test_data)
# Out:
# Epoch 1/20
# 49/49 [==============================] - 39s 642ms/step - loss: 1.3770 - accuracy: 0.4177 - val_loss: 2.1750 - val_accuracy: 0.3594
# Epoch 2/20
# 49/49 [==============================] - 33s 644ms/step - loss: 1.0681 - accuracy: 0.5261 - val_loss: 3.3621 - val_accuracy: 0.3438
# Epoch 3/20
# 49/49 [==============================] - 40s 797ms/step - loss: 1.0394 - accuracy: 0.5612 - val_loss: 5.1307 - val_accuracy: 0.3281
# Epoch 4/20
# 49/49 [==============================] - 40s 798ms/step - loss: 0.8809 - accuracy: 0.6352 - val_loss: 4.0840 - val_accuracy: 0.4062
# Epoch 5/20
# 49/49 [==============================] - 40s 803ms/step - loss: 0.8289 - accuracy: 0.6575 - val_loss: 3.0763 - val_accuracy: 0.3125
# Epoch 6/20
# 49/49 [==============================] - 40s 802ms/step - loss: 0.7219 - accuracy: 0.7143 - val_loss: 4.1288 - val_accuracy: 0.3594
# Epoch 7/20
# 49/49 [==============================] - 40s 802ms/step - loss: 0.6656 - accuracy: 0.7526 - val_loss: 3.3477 - val_accuracy: 0.3281
# Epoch 8/20
# 49/49 [==============================] - 40s 798ms/step - loss: 0.6373 - accuracy: 0.7634 - val_loss: 2.1033 - val_accuracy: 0.2969
# Epoch 9/20
# 49/49 [==============================] - 40s 794ms/step - loss: 0.5742 - accuracy: 0.7812 - val_loss: 2.1586 - val_accuracy: 0.3125
# Epoch 10/20
# 49/49 [==============================] - 40s 796ms/step - loss: 0.5186 - accuracy: 0.8080 - val_loss: 1.2903 - val_accuracy: 0.4688
# Epoch 11/20
# 49/49 [==============================] - 40s 798ms/step - loss: 0.4703 - accuracy: 0.8297 - val_loss: 1.2395 - val_accuracy: 0.6250
# Epoch 12/20
# 49/49 [==============================] - 40s 798ms/step - loss: 0.4448 - accuracy: 0.8342 - val_loss: 1.6364 - val_accuracy: 0.4062
# Epoch 13/20
# 49/49 [==============================] - 40s 800ms/step - loss: 0.4705 - accuracy: 0.8227 - val_loss: 7.9570 - val_accuracy: 0.2500
# Epoch 14/20
# 49/49 [==============================] - 40s 801ms/step - loss: 0.4188 - accuracy: 0.8603 - val_loss: 3.2251 - val_accuracy: 0.4844
# Epoch 15/20
# 49/49 [==============================] - 40s 799ms/step - loss: 0.4453 - accuracy: 0.8469 - val_loss: 0.6135 - val_accuracy: 0.7812
# Epoch 16/20
# 49/49 [==============================] - 40s 795ms/step - loss: 0.3710 - accuracy: 0.8705 - val_loss: 0.6254 - val_accuracy: 0.7969
# Epoch 17/20
# 49/49 [==============================] - 40s 794ms/step - loss: 0.3429 - accuracy: 0.8731 - val_loss: 0.5280 - val_accuracy: 0.8750
# Epoch 18/20
# 49/49 [==============================] - 40s 795ms/step - loss: 0.3439 - accuracy: 0.8801 - val_loss: 1.0024 - val_accuracy: 0.7188
# Epoch 19/20
# 49/49 [==============================] - 40s 793ms/step - loss: 0.2874 - accuracy: 0.9011 - val_loss: 0.3068 - val_accuracy: 0.8906
# Epoch 20/20
# 49/49 [==============================] - 31s 612ms/step - loss: 0.3112 - accuracy: 0.8916 - val_loss: 0.5010 - val_accuracy: 0.8750

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(acc))

plt.figure(figsize=(8, 6))
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Testing accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Q.8** Test your code with test set

# %%
loss, accuracy = model.evaluate(test_data)
# Out:
# 2/2 [==============================] - 13s 79ms/step - loss: 0.3641 - accuracy: 0.9062

# %%
# Do not change this code
if accuracy>=0.85:
  print(f"Congratulations, CNN assignment complete!! Your accuracy is {accuracy}")
else:
  print(f"Try again, not enough accuracy! Your accuracy is {accuracy}" )
# Out:
# Congratulations, CNN assignment complete!! Your accuracy is 0.90625

# %% [markdown]
# **Note: 1. Many of you will get very high train accuracy but low test accuracy. This is called overfitting, this can be solved by increasing the train set size. If your getting low accuracy for both train and test, modify your layers in the model.**
#
# **2.Do use T4GPU.Ideally your first epoch will take quite sometime and rest of the epochs will be faster but if all your epochs are taking a lot of time, try starting a new gpu session(open a new gmail account and open colab on that) because your free gpu might have exhausted itself.**
#
# **3.Other than that everything should be fine, happy learning!!**
